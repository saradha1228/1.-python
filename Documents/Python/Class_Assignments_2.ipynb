# %%
from classfile import function

function.Subfields()
function.oddeven()
function.elegible()
function.percentage()
function.triangle()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision, Robotics
# Speech Processing
# Natural Language Processing
# Enter a number:  3
# 3 is an odd number
# Your Gender:  female
# Your age:  34
# Eligible
# Subject1 =  23
# Subject2 =  56
# Subject3 =  43
# Subject4 =  65
# Subject5 =  78
# Total: 265
# Percentage: 53.0
# Height =  2
# Breadth =  4
# Area of Triangle: 4.0
# Height1 =  3
# Height2 =  5
# Breadth =  67
# Perimeter of Triangle: 75
